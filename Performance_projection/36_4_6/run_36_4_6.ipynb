# %% [markdown]
# quantum LDPCcode [[36,4,6]]

# %%
import numpy as np
from mip import Model, xsum, minimize, BINARY
from mip import OptimizationStatus
from bposd.css import css_code
import pickle
import itertools 
from scipy.sparse import coo_matrix, hstack 
from ldpc import mod2

# %%
import multiprocessing
import subprocess
import sys
import os
import itertools

# %% [markdown]
# ## Code construction

# %%
# [[36, 4, 6]]
ell,m = 6, 3
a1,a2,a3 = 1, 0, 1
b1,b2,b3 = 2, 2, 3

k = 4 ; d = 6 ;
n = 2*ell*m ; 
n2 = ell*m ;

# %%
list_scaling_factor = [0.3, 0.4, 0.5, 0.75, 1] ;

# %% [markdown]
# ### Decoders

# %%
script = "Decoder_36_4_6.py"

processes = []
for scaling_factor in list_scaling_factor:
    p = subprocess.Popen([sys.executable, script, str(scaling_factor)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()
# Out:
# Number of noisy circuits for the logical X state = 23760
# Number of noisy circuits for the logical Z state = 23760
# Number of distinct syndrome histories for logical X = 1207
# Number of distinct syndrome histories for logical Z = 1207
# Number of noisy circuits for the logical X state = 23760
# Number of noisy circuits for the logical Z state = 23760
# Number of distinct syndrome histories for logical X = 1207
# Number of distinct syndrome histories for logical Z = 1207
# Number of noisy circuits for the logical X state = 23760
# Number of noisy circuits for the logical Z state = 23760
# Number of distinct syndrome histories for logical X = 1207
# Number of distinct syndrome histories for logical Z = 1207
# Number of noisy circuits for the logical X state = 23760
# Number of noisy circuits for the logical Z state = 23760
# Number of distinct syndrome histories for logical X = 1207
# Number of distinct syndrome histories for logical Z = 1207
# Number of noisy circuits for the logical X state = 23760
# Number of noisy circuits for the logical Z state = 23760
# Number of distinct syndrome histories for logical X = 1207
# Number of distinct syndrome histories for logical Z = 1207

# %% [markdown]
# ### Run numerical simulation to obtain data

# %%
script = "Classical_simulation_36_4_6.py"

processes = []
for scaling_factor in list_scaling_factor:
    p = subprocess.Popen([sys.executable, script, str(scaling_factor)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()

# %% [markdown]
# ### Perform error correction on numerical data

# %%
num_samples = 40000 ;
num_per_run = 400;
num_iter_collect = int(num_samples / num_per_run) ;

# %%
import time
start_time = time.time()  
##-------------------------------------------------------------------------------

script = "Error_correction_classical_simulation_36_4_6.py"

def run_error_correction(scaling_factor, iter_collect):
    subprocess.run([sys.executable, script, str(scaling_factor), str(iter_collect)])

args = list(itertools.product(list_scaling_factor, range(num_iter_collect)))

with multiprocessing.Pool(processes=180) as pool:
    pool.starmap(run_error_correction, args)

##-------------------------------------------------------------------------------
end_time = time.time()    
print(f"The total running time: {end_time - start_time:.2f} seconds")
# Out:
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8725
# Logical error over 7 cycles (single logical qubit): [0.495 0.495 0.51  0.44 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.0125 0.02   0.0175 0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8125
# Logical error over 7 cycles (single logical qubit): [0.4325 0.4325 0.4325 0.435 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0325 0.01   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.465  0.4675 0.4775 0.41  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0275 0.02   0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.815
# Logical error over 7 cycles (single logical qubit): [0.4475 0.4575 0.46   0.385 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.015  0.0125 0.01   0.0125]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.4225 0.48   0.49   0.4375]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.015  0.0075 0.0125 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.4725 0.45   0.495  0.4275]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.025  0.015  0.0325]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.445  0.48   0.5325 0.3825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.02   0.0175 0.0175 0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.81
# Logical error over 7 cycles (single logical qubit): [0.425  0.435  0.44   0.4175]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0225 0.0175 0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8575
# Logical error over 7 cycles (single logical qubit): [0.4825 0.4775 0.47   0.41  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.0175 0.025  0.01   0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.825
# Logical error over 7 cycles (single logical qubit): [0.455  0.485  0.4425 0.3875]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.03   0.0225 0.025  0.0325]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.4775 0.49   0.4725 0.3825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.015  0.02   0.02   0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.465  0.5    0.4525 0.41  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.03   0.0225 0.0225 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.4725 0.4625 0.4575 0.3925]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.025  0.02   0.0225 0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.46   0.44   0.5225 0.4275]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.0225 0.015  0.0175 0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.465  0.4625 0.49   0.4225]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.015  0.025  0.0225 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.455  0.4675 0.4325 0.3975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0175 0.0125 0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.4725 0.4825 0.48   0.435 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.0275 0.0225 0.015  0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.4625 0.5125 0.465  0.4325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.025  0.0225 0.0225 0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.4875 0.44   0.4325 0.3975]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0175 0.0075 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.4175 0.425  0.4375 0.3975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.02   0.02   0.0125 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.4575 0.5025 0.4725 0.405 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.02   0.02   0.0225 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.47   0.45   0.4525 0.3975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.01   0.02   0.0125 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8625
# Logical error over 7 cycles (single logical qubit): [0.4375 0.515  0.4675 0.41  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.0075 0.01   0.0025 0.0125]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.835
# Logical error over 7 cycles (single logical qubit): [0.4775 0.4675 0.4225 0.4   ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0275 0.0225 0.0125 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.4875 0.4525 0.4975 0.4325]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.020000000000000018
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0125 0.0075 0.01  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.4875 0.4775 0.4875 0.405 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.01   0.0175 0.01   0.02  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.88
# Logical error over 7 cycles (single logical qubit): [0.4925 0.49   0.4475 0.4325]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0125 0.015  0.015 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8175
# Logical error over 7 cycles (single logical qubit): [0.475 0.465 0.45  0.395]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0075 0.015  0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8875
# Logical error over 7 cycles (single logical qubit): [0.4925 0.4975 0.515  0.4325]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0325 0.0225 0.0125 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8049999999999999
# Logical error over 7 cycles (single logical qubit): [0.4125 0.4225 0.475  0.365 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05249999999999999
# Logical error over 7 cycles (single logical qubit): [0.0425 0.0275 0.03   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8725
# Logical error over 7 cycles (single logical qubit): [0.4375 0.4625 0.4725 0.3975]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0325 0.0225 0.0175 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.83
# Logical error over 7 cycles (single logical qubit): [0.445  0.465  0.4325 0.41  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.0325 0.0375 0.0225 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.83
# Logical error over 7 cycles (single logical qubit): [0.4575 0.4775 0.505  0.395 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.015  0.0175 0.015  0.0075]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.46   0.4625 0.5175 0.42  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.015 0.015 0.01  0.01 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.46   0.46   0.4625 0.3825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0175 0.01   0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.46   0.4925 0.46   0.3925]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.015  0.0225 0.015  0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.4625 0.4925 0.4725 0.3825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.035  0.025  0.02   0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.435  0.4625 0.4675 0.43  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0225 0.0075 0.02  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8575
# Logical error over 7 cycles (single logical qubit): [0.435  0.5175 0.45   0.3875]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.02   0.0125 0.0175 0.0125]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.83
# Logical error over 7 cycles (single logical qubit): [0.45   0.455  0.4575 0.39  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.025  0.02   0.0225 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8175
# Logical error over 7 cycles (single logical qubit): [0.4425 0.47   0.4325 0.43  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.015 0.02  0.01  0.015]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.86
# Logical error over 7 cycles (single logical qubit): [0.4425 0.4925 0.5    0.445 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.057499999999999996
# Logical error over 7 cycles (single logical qubit): [0.03   0.035  0.015  0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.835
# Logical error over 7 cycles (single logical qubit): [0.47   0.44   0.5175 0.3825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0275 0.02   0.0025 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8275
# Logical error over 7 cycles (single logical qubit): [0.4725 0.4125 0.4425 0.3925]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.0175 0.02   0.02   0.02  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.885
# Logical error over 7 cycles (single logical qubit): [0.455  0.5175 0.5075 0.415 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.02  0.025 0.025 0.03 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.4525 0.4775 0.4775 0.4075]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.03   0.03   0.0175 0.0325]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.4925 0.5125 0.48   0.43  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.01   0.0075 0.01   0.0075]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.4825 0.43   0.4675 0.425 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05249999999999999
# Logical error over 7 cycles (single logical qubit): [0.0325 0.0275 0.0175 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.505  0.5325 0.5075 0.42  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0275 0.03   0.02   0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.43   0.4975 0.475  0.415 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.015  0.02   0.0125 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.885
# Logical error over 7 cycles (single logical qubit): [0.4775 0.475  0.495  0.445 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0225 0.02   0.0225 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.81
# Logical error over 7 cycles (single logical qubit): [0.4175 0.475  0.475  0.4   ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.06000000000000005
# Logical error over 7 cycles (single logical qubit): [0.0325 0.0325 0.03   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8425
# Logical error over 7 cycles (single logical qubit): [0.485  0.45   0.44   0.4475]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.057499999999999996
# Logical error over 7 cycles (single logical qubit): [0.0225 0.035  0.03   0.03  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.4575 0.4175 0.4575 0.425 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.01   0.0175 0.0075 0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.835
# Logical error over 7 cycles (single logical qubit): [0.4475 0.4575 0.485  0.425 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.03  0.03  0.025 0.035]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8125
# Logical error over 7 cycles (single logical qubit): [0.44   0.4125 0.4375 0.4175]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0325 0.0175 0.0125]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8725
# Logical error over 7 cycles (single logical qubit): [0.4625 0.51   0.48   0.435 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0175 0.01   0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.4975 0.41   0.44   0.415 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0275 0.015  0.0375]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.435 0.445 0.475 0.45 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0175 0.02   0.015  0.0125]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8325
# Logical error over 7 cycles (single logical qubit): [0.4325 0.4925 0.4625 0.4225]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.057499999999999996
# Logical error over 7 cycles (single logical qubit): [0.025  0.0325 0.02   0.0375]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8625
# Logical error over 7 cycles (single logical qubit): [0.455 0.495 0.49  0.44 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.0225 0.01   0.0075 0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8674999999999999
# Logical error over 7 cycles (single logical qubit): [0.4525 0.5    0.4825 0.425 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.035  0.0325 0.0275 0.035 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8425
# Logical error over 7 cycles (single logical qubit): [0.4625 0.4325 0.4375 0.4075]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.03   0.0225 0.03  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8325
# Logical error over 7 cycles (single logical qubit): [0.4775 0.4075 0.4575 0.4325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.025 0.025 0.02  0.025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.875
# Logical error over 7 cycles (single logical qubit): [0.485  0.495  0.5275 0.3875]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0175 0.0175 0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8425
# Logical error over 7 cycles (single logical qubit): [0.465  0.48   0.4125 0.445 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.035  0.0275 0.015  0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.48   0.4425 0.4325 0.4225]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.015  0.0175 0.02   0.015 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.825
# Logical error over 7 cycles (single logical qubit): [0.47   0.45   0.4675 0.4025]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.04   0.0475 0.0175 0.045 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.475  0.455  0.5025 0.4325]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.025  0.0275 0.025  0.03  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.835
# Logical error over 7 cycles (single logical qubit): [0.45   0.4675 0.44   0.46  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05249999999999999
# Logical error over 7 cycles (single logical qubit): [0.03   0.035  0.02   0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.47   0.465  0.425  0.4525]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.02   0.0175 0.0025 0.015 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.87
# Logical error over 7 cycles (single logical qubit): [0.4975 0.475  0.4675 0.3925]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.02   0.0275 0.015  0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.455  0.4725 0.44   0.42  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0225 0.035  0.015  0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8575
# Logical error over 7 cycles (single logical qubit): [0.445  0.4825 0.465  0.41  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0375 0.03   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.855
# Logical error over 7 cycles (single logical qubit): [0.46   0.505  0.4625 0.4775]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.02   0.015  0.0225 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8325
# Logical error over 7 cycles (single logical qubit): [0.475  0.4075 0.4925 0.4225]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.025  0.02   0.0175 0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8625
# Logical error over 7 cycles (single logical qubit): [0.4175 0.4925 0.4875 0.435 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0175 0.01   0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8575
# Logical error over 7 cycles (single logical qubit): [0.4625 0.4875 0.4975 0.3925]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.025  0.0225 0.0225 0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8175
# Logical error over 7 cycles (single logical qubit): [0.4675 0.475  0.4675 0.42  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0225 0.015  0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8175
# Logical error over 7 cycles (single logical qubit): [0.425  0.43   0.4675 0.4   ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05249999999999999
# Logical error over 7 cycles (single logical qubit): [0.0325 0.03   0.02   0.03  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8425
# Logical error over 7 cycles (single logical qubit): [0.495 0.445 0.46  0.43 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0275 0.0225 0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.455  0.4925 0.455  0.4275]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.025  0.02   0.0175 0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.48   0.5125 0.445  0.4225]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0175 0.03   0.0275 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8275
# Logical error over 7 cycles (single logical qubit): [0.44  0.415 0.49  0.385]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.0325 0.02   0.0225 0.03  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8375
# Logical error over 7 cycles (single logical qubit): [0.4175 0.4625 0.47   0.43  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.015  0.0175 0.0125 0.015 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.48   0.4275 0.4375 0.4425]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.025 0.02  0.02  0.015]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8825000000000001
# Logical error over 7 cycles (single logical qubit): [0.515  0.48   0.4625 0.445 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0325 0.025  0.03  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.815
# Logical error over 7 cycles (single logical qubit): [0.44  0.435 0.425 0.41 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.03   0.0325 0.0175 0.0325]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8875
# Logical error over 7 cycles (single logical qubit): [0.4975 0.505  0.51   0.42  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.0425 0.0275 0.025  0.035 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.825
# Logical error over 7 cycles (single logical qubit): [0.465  0.4475 0.4525 0.4025]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.0175 0.025  0.0175 0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.5    0.4825 0.4725 0.3975]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.015  0.025  0.015  0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.465  0.4825 0.4375 0.3525]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04749999999999999
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0225 0.025  0.0325]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.4375 0.4625 0.4575 0.34  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.025  0.025  0.015 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8475
# Logical error over 7 cycles (single logical qubit): [0.44   0.4675 0.505  0.3975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.03   0.0225 0.025  0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.885
# Logical error over 7 cycles (single logical qubit): [0.5    0.465  0.4825 0.4375]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.02   0.02   0.02   0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.78
# Logical error over 7 cycles (single logical qubit): [0.46   0.4475 0.435  0.38  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.02   0.0175 0.0175 0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.885
# Logical error over 7 cycles (single logical qubit): [0.495  0.455  0.4775 0.41  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.035 0.02  0.01  0.025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.475  0.4075 0.435  0.405 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0275 0.015  0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.505  0.45   0.435  0.4625]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0275 0.0175 0.015  0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.445  0.45   0.5075 0.3875]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04749999999999999
# Logical error over 7 cycles (single logical qubit): [0.0275 0.0125 0.0275 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.86
# Logical error over 7 cycles (single logical qubit): [0.475  0.495  0.4775 0.4375]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.015  0.0125 0.015  0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.825
# Logical error over 7 cycles (single logical qubit): [0.45   0.385  0.455  0.4375]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.02   0.0275 0.015  0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.5075 0.4875 0.4625 0.405 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.02   0.0225 0.0225 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.83
# Logical error over 7 cycles (single logical qubit): [0.52   0.4    0.49   0.4125]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0175 0.02   0.0125 0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8275
# Logical error over 7 cycles (single logical qubit): [0.485  0.49   0.4725 0.3775]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0225 0.015  0.0275]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.3825 0.42   0.455  0.435 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.0325 0.04   0.02   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.4775 0.4625 0.4725 0.4475]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0225 0.0175 0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.46   0.4625 0.4575 0.4   ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04749999999999999
# Logical error over 7 cycles (single logical qubit): [0.0325 0.025  0.0225 0.035 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.4625 0.435  0.425  0.41  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.015  0.02   0.0175 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8325
# Logical error over 7 cycles (single logical qubit): [0.4875 0.47   0.485  0.43  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0625
# Logical error over 7 cycles (single logical qubit): [0.03   0.035  0.0225 0.035 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8625
# Logical error over 7 cycles (single logical qubit): [0.5025 0.47   0.4575 0.455 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.03   0.0275 0.03   0.03  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8725
# Logical error over 7 cycles (single logical qubit): [0.4725 0.4875 0.505  0.405 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.02  0.02  0.015 0.02 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.455  0.4575 0.48   0.3925]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.02   0.0125 0.015  0.02  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.425  0.5025 0.485  0.3975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.025  0.0125 0.0225 0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.435  0.45   0.4525 0.43  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.04749999999999999
# Logical error over 7 cycles (single logical qubit): [0.0225 0.04   0.0125 0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.7975
# Logical error over 7 cycles (single logical qubit): [0.4125 0.385  0.435  0.4075]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.0275 0.03   0.02   0.0375]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.5125 0.47   0.465  0.4275]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0175 0.015  0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.465  0.4175 0.4375 0.3825]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.07499999999999996
# Logical error over 7 cycles (single logical qubit): [0.03   0.045  0.03   0.0475]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.855
# Logical error over 7 cycles (single logical qubit): [0.4575 0.515  0.45   0.39  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0125 0.0175 0.025 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8225
# Logical error over 7 cycles (single logical qubit): [0.49  0.425 0.46  0.415]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04249999999999998
# Logical error over 7 cycles (single logical qubit): [0.0225 0.0225 0.0225 0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8525
# Logical error over 7 cycles (single logical qubit): [0.4525 0.4725 0.5375 0.3925]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.03   0.02   0.015  0.0225]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.825
# Logical error over 7 cycles (single logical qubit): [0.4275 0.4875 0.45   0.3675]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.0075 0.02   0.01   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8625
# Logical error over 7 cycles (single logical qubit): [0.48   0.49   0.4475 0.4375]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.050000000000000044
# Logical error over 7 cycles (single logical qubit): [0.025  0.0275 0.0225 0.035 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8200000000000001
# Logical error over 7 cycles (single logical qubit): [0.4325 0.4175 0.4225 0.41  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05249999999999999
# Logical error over 7 cycles (single logical qubit): [0.0275 0.0325 0.03   0.03  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8674999999999999
# Logical error over 7 cycles (single logical qubit): [0.4875 0.475  0.485  0.43  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.03500000000000003
# Logical error over 7 cycles (single logical qubit): [0.015  0.03   0.0225 0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.845
# Logical error over 7 cycles (single logical qubit): [0.47   0.42   0.4675 0.4175]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.05500000000000005
# Logical error over 7 cycles (single logical qubit): [0.035  0.03   0.025  0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.875
# Logical error over 7 cycles (single logical qubit): [0.4925 0.48   0.505  0.4075]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.06499999999999995
# Logical error over 7 cycles (single logical qubit): [0.0375 0.035  0.02   0.045 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.47   0.4825 0.4875 0.41  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.04500000000000004
# Logical error over 7 cycles (single logical qubit): [0.0275 0.025  0.015  0.0225]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8175
# ...
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.484 0.504 0.548 0.524]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.444 0.452 0.5   0.488]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.472 0.496 0.508 0.552]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8280000000000001
# Logical error over 7 cycles (single logical qubit): [0.456 0.404 0.444 0.38 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.964
# Logical error over 7 cycles (single logical qubit): [0.48  0.5   0.512 0.596]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.864
# Logical error over 7 cycles (single logical qubit): [0.452 0.452 0.444 0.444]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.908
# Logical error over 7 cycles (single logical qubit): [0.468 0.52  0.472 0.508]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.836
# Logical error over 7 cycles (single logical qubit): [0.436 0.492 0.48  0.404]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.92
# Logical error over 7 cycles (single logical qubit): [0.46  0.5   0.484 0.504]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.86
# Logical error over 7 cycles (single logical qubit): [0.468 0.464 0.464 0.464]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.972
# Logical error over 7 cycles (single logical qubit): [0.476 0.476 0.532 0.516]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.832
# Logical error over 7 cycles (single logical qubit): [0.464 0.456 0.416 0.46 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.536 0.46  0.48  0.568]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.468 0.536 0.456 0.388]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.484 0.544 0.472 0.524]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8160000000000001
# Logical error over 7 cycles (single logical qubit): [0.452 0.46  0.408 0.456]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.94
# Logical error over 7 cycles (single logical qubit): [0.52  0.516 0.512 0.496]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.524 0.472 0.44  0.384]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.92
# Logical error over 7 cycles (single logical qubit): [0.528 0.512 0.488 0.468]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.488 0.444 0.416 0.428]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.512 0.44  0.512 0.484]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.848
# Logical error over 7 cycles (single logical qubit): [0.512 0.468 0.5   0.48 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.92
# Logical error over 7 cycles (single logical qubit): [0.44 0.5  0.54 0.5 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.832
# Logical error over 7 cycles (single logical qubit): [0.436 0.488 0.416 0.432]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.956
# Logical error over 7 cycles (single logical qubit): [0.54  0.488 0.512 0.548]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.44  0.448 0.416 0.484]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.504 0.48  0.516 0.44 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.804
# Logical error over 7 cycles (single logical qubit): [0.448 0.476 0.464 0.432]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.976
# Logical error over 7 cycles (single logical qubit): [0.516 0.492 0.484 0.484]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.492 0.408 0.436 0.472]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.484 0.488 0.52  0.492]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.796
# Logical error over 7 cycles (single logical qubit): [0.46  0.428 0.364 0.48 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.972
# Logical error over 7 cycles (single logical qubit): [0.508 0.592 0.496 0.496]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.492 0.508 0.46  0.468]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.508 0.476 0.48  0.52 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.772
# Logical error over 7 cycles (single logical qubit): [0.404 0.448 0.384 0.44 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.528 0.496 0.472 0.512]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.888
# Logical error over 7 cycles (single logical qubit): [0.436 0.464 0.472 0.476]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.916
# Logical error over 7 cycles (single logical qubit): [0.476 0.528 0.504 0.52 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.396 0.456 0.392 0.412]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.476 0.436 0.484 0.492]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.872
# Logical error over 7 cycles (single logical qubit): [0.436 0.5   0.448 0.416]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.916
# Logical error over 7 cycles (single logical qubit): [0.468 0.48  0.48  0.504]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.796
# Logical error over 7 cycles (single logical qubit): [0.412 0.42  0.448 0.416]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.44  0.496 0.592 0.452]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.808
# Logical error over 7 cycles (single logical qubit): [0.456 0.464 0.456 0.42 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.96
# Logical error over 7 cycles (single logical qubit): [0.468 0.54  0.516 0.472]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.892
# Logical error over 7 cycles (single logical qubit): [0.468 0.512 0.444 0.504]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.488 0.456 0.54  0.456]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.448 0.444 0.452 0.46 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.456 0.568 0.448 0.452]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.496 0.42  0.436 0.472]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9
# Logical error over 7 cycles (single logical qubit): [0.464 0.488 0.536 0.508]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8280000000000001
# Logical error over 7 cycles (single logical qubit): [0.456 0.456 0.412 0.44 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.508 0.52  0.508 0.5  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.76
# Logical error over 7 cycles (single logical qubit): [0.416 0.452 0.364 0.432]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.48  0.528 0.488 0.492]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.872
# Logical error over 7 cycles (single logical qubit): [0.496 0.436 0.46  0.48 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.916
# Logical error over 7 cycles (single logical qubit): [0.472 0.568 0.516 0.472]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.836
# Logical error over 7 cycles (single logical qubit): [0.492 0.404 0.444 0.436]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.544 0.48  0.548 0.472]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.428 0.468 0.404 0.488]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.488 0.52  0.524 0.504]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.804
# Logical error over 7 cycles (single logical qubit): [0.464 0.512 0.432 0.412]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.54  0.416 0.504 0.484]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8280000000000001
# Logical error over 7 cycles (single logical qubit): [0.412 0.432 0.436 0.456]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.956
# Logical error over 7 cycles (single logical qubit): [0.524 0.48  0.572 0.504]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.84
# Logical error over 7 cycles (single logical qubit): [0.464 0.46  0.468 0.508]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.46  0.532 0.456 0.472]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.844
# Logical error over 7 cycles (single logical qubit): [0.488 0.476 0.456 0.508]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.46  0.524 0.492 0.488]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.488 0.476 0.404 0.42 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.516 0.472 0.488 0.552]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.46  0.432 0.488 0.476]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.54  0.464 0.5   0.48 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.808
# Logical error over 7 cycles (single logical qubit): [0.42  0.428 0.392 0.492]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.508 0.492 0.476 0.484]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.896
# Logical error over 7 cycles (single logical qubit): [0.52  0.476 0.448 0.476]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.508 0.496 0.484 0.5  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.792
# Logical error over 7 cycles (single logical qubit): [0.424 0.492 0.416 0.484]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.528 0.492 0.504 0.512]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.852
# Logical error over 7 cycles (single logical qubit): [0.42  0.468 0.412 0.544]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.484 0.488 0.52  0.56 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.836
# Logical error over 7 cycles (single logical qubit): [0.468 0.44  0.44  0.452]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.96
# Logical error over 7 cycles (single logical qubit): [0.508 0.552 0.528 0.444]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.848
# Logical error over 7 cycles (single logical qubit): [0.432 0.48  0.492 0.464]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.484 0.472 0.488 0.492]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.812
# Logical error over 7 cycles (single logical qubit): [0.44  0.464 0.392 0.416]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.468 0.564 0.484 0.516]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.852
# Logical error over 7 cycles (single logical qubit): [0.48  0.416 0.46  0.448]
# The total running time: 325.50 seconds
