# %% [markdown]
# quantum LDPCcode [[54,4,8]]

# %%
import numpy as np
from mip import Model, xsum, minimize, BINARY
from mip import OptimizationStatus
from bposd.css import css_code
import pickle
import itertools 
from scipy.sparse import coo_matrix, hstack 
from ldpc import mod2
import matplotlib.pyplot as plt

# %%
import multiprocessing
import subprocess
import sys
import os
import itertools

# %% [markdown]
# ## Code construction

# %%
# [[54,4,8]]
ell,m = 9, 3
a1,a2,a3 = 1, 0, 2
b1,b2,b3 = 1, 6, 5

k = 4 ; d = 8 ;
n = 2*ell*m ; 
n2 = ell*m ;

# %%
list_scaling_factor = [0.3, 0.4, 0.5, 0.75, 1] ;

# %% [markdown]
# ### Decoders

# %%
import subprocess
script = "Decoder_54_4_8.py"

processes = []
for scaling_factor in list_scaling_factor:
    p = subprocess.Popen([sys.executable, script, str(scaling_factor)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()
# Out:
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810
# Number of noisy circuits for the logical X state = 35640
# Number of noisy circuits for the logical Z state = 35640
# Number of distinct syndrome histories for logical X = 1810
# Number of distinct syndrome histories for logical Z = 1810

# %% [markdown]
# ### Run numerical simulation to obtain data

# %%
script = "Classical_simulation_54_4_8.py"

processes = []
for scaling_factor in list_scaling_factor:
    p = subprocess.Popen([sys.executable, script, str(scaling_factor)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()

# %% [markdown]
# ### Perform error correction on numerical data

# %%
num_samples = 40000 ;
num_per_run = 400;
num_iter_collect = int(num_samples / 400) ;

# %%
import time
start_time = time.time()  
##-------------------------------------------------------------------------------

script = "Error_correction_classical_simulation_54_4_8.py"

def run_error_correction(scaling_factor, iter_collect):
    subprocess.run([sys.executable, script, str(scaling_factor), str(iter_collect)])


args = list(itertools.product(list_scaling_factor, range(num_iter_collect)))

with multiprocessing.Pool(processes=150) as pool:
    pool.starmap(run_error_correction, args)


##-------------------------------------------------------------------------------
end_time = time.time()    
print(f"The total running time: {end_time - start_time:.2f} seconds")
# Out:
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6275
# Logical error over 7 cycles (single logical qubit): [0.3725 0.3475 0.275  0.25  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.605
# Logical error over 7 cycles (single logical qubit): [0.3525 0.3575 0.3425 0.3325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6074999999999999
# Logical error over 7 cycles (single logical qubit): [0.37   0.315  0.2625 0.2575]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6125
# Logical error over 7 cycles (single logical qubit): [0.3675 0.3625 0.34   0.345 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.645
# Logical error over 7 cycles (single logical qubit): [0.365  0.3875 0.2775 0.295 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.62
# Logical error over 7 cycles (single logical qubit): [0.375  0.3675 0.3675 0.35  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.585
# Logical error over 7 cycles (single logical qubit): [0.3525 0.31   0.255  0.2725]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.     0.0025 0.     0.    ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.605
# Logical error over 7 cycles (single logical qubit): [0.3325 0.3575 0.3575 0.34  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.645
# Logical error over 7 cycles (single logical qubit): [0.38   0.3525 0.2725 0.31  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.615
# Logical error over 7 cycles (single logical qubit): [0.325  0.33   0.3325 0.34  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.64
# Logical error over 7 cycles (single logical qubit): [0.405  0.3775 0.2625 0.26  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.595
# Logical error over 7 cycles (single logical qubit): [0.35   0.3325 0.35   0.3325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.7
# Logical error over 7 cycles (single logical qubit): [0.3975 0.445  0.2725 0.2775]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.5675
# Logical error over 7 cycles (single logical qubit): [0.305  0.3525 0.305  0.3175]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.62
# Logical error over 7 cycles (single logical qubit): [0.325  0.4025 0.27   0.275 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.5875
# Logical error over 7 cycles (single logical qubit): [0.3775 0.3275 0.3075 0.3025]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.     0.0025 0.    ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.685
# Logical error over 7 cycles (single logical qubit): [0.405  0.4025 0.3075 0.275 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.61
# Logical error over 7 cycles (single logical qubit): [0.38   0.3425 0.37   0.345 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6725
# Logical error over 7 cycles (single logical qubit): [0.38   0.395  0.29   0.2925]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6275
# Logical error over 7 cycles (single logical qubit): [0.3725 0.3825 0.3325 0.355 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6475
# Logical error over 7 cycles (single logical qubit): [0.3975 0.3975 0.2675 0.27  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.625
# Logical error over 7 cycles (single logical qubit): [0.375  0.35   0.345  0.3625]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6775
# Logical error over 7 cycles (single logical qubit): [0.4225 0.39   0.2625 0.27  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.635
# Logical error over 7 cycles (single logical qubit): [0.3825 0.3475 0.38   0.3475]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6525000000000001
# Logical error over 7 cycles (single logical qubit): [0.35  0.39  0.28  0.275]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.61
# Logical error over 7 cycles (single logical qubit): [0.3575 0.3275 0.375  0.325 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6275
# Logical error over 7 cycles (single logical qubit): [0.355 0.385 0.245 0.27 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.5725
# Logical error over 7 cycles (single logical qubit): [0.3275 0.3225 0.2975 0.345 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6575
# Logical error over 7 cycles (single logical qubit): [0.4175 0.3675 0.2825 0.3   ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.595
# Logical error over 7 cycles (single logical qubit): [0.355  0.36   0.3425 0.3325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.655
# Logical error over 7 cycles (single logical qubit): [0.4225 0.3825 0.24   0.2825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6
# Logical error over 7 cycles (single logical qubit): [0.345 0.335 0.345 0.315]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.665
# Logical error over 7 cycles (single logical qubit): [0.3625 0.42   0.3025 0.305 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6225
# Logical error over 7 cycles (single logical qubit): [0.335  0.4025 0.3175 0.3625]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.     0.0025 0.    ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6174999999999999
# Logical error over 7 cycles (single logical qubit): [0.375 0.34  0.245 0.275]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.605
# Logical error over 7 cycles (single logical qubit): [0.335  0.3375 0.335  0.3325]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6599999999999999
# Logical error over 7 cycles (single logical qubit): [0.3775 0.42   0.2675 0.275 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.525
# Logical error over 7 cycles (single logical qubit): [0.315  0.3175 0.3125 0.3   ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6599999999999999
# Logical error over 7 cycles (single logical qubit): [0.3825 0.3625 0.29   0.3025]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6
# Logical error over 7 cycles (single logical qubit): [0.3425 0.3775 0.3625 0.34  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.655
# Logical error over 7 cycles (single logical qubit): [0.3675 0.375  0.2975 0.2475]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.565
# Logical error over 7 cycles (single logical qubit): [0.35   0.3275 0.32   0.3125]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6599999999999999
# Logical error over 7 cycles (single logical qubit): [0.3675 0.4175 0.2625 0.2825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.5900000000000001
# Logical error over 7 cycles (single logical qubit): [0.315  0.3375 0.335  0.325 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.     0.0025 0.    ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6325000000000001
# Logical error over 7 cycles (single logical qubit): [0.3825 0.3725 0.2325 0.255 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.585
# Logical error over 7 cycles (single logical qubit): [0.38   0.295  0.3575 0.3125]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.     0.     0.0025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6799999999999999
# Logical error over 7 cycles (single logical qubit): [0.385  0.395  0.27   0.2575]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.65
# Logical error over 7 cycles (single logical qubit): [0.385  0.4    0.365  0.3775]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.625
# Logical error over 7 cycles (single logical qubit): [0.3475 0.4    0.28   0.26  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.5925
# Logical error over 7 cycles (single logical qubit): [0.3675 0.3475 0.34   0.315 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.65
# Logical error over 7 cycles (single logical qubit): [0.375  0.39   0.2525 0.28  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.63
# Logical error over 7 cycles (single logical qubit): [0.35   0.385  0.335  0.3525]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.0025 0.0025 0.0025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.65
# Logical error over 7 cycles (single logical qubit): [0.375  0.3825 0.2725 0.2875]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.     0.     0.     0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.61
# Logical error over 7 cycles (single logical qubit): [0.3525 0.37   0.325  0.3425]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6599999999999999
# Logical error over 7 cycles (single logical qubit): [0.3725 0.3975 0.2875 0.2525]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.63
# Logical error over 7 cycles (single logical qubit): [0.3825 0.3725 0.3525 0.325 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6525000000000001
# Logical error over 7 cycles (single logical qubit): [0.3575 0.4025 0.3025 0.265 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.585
# Logical error over 7 cycles (single logical qubit): [0.365  0.33   0.365  0.2775]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.675
# Logical error over 7 cycles (single logical qubit): [0.41   0.3725 0.315  0.2525]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6174999999999999
# Logical error over 7 cycles (single logical qubit): [0.35   0.3375 0.3425 0.34  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.605
# Logical error over 7 cycles (single logical qubit): [0.325  0.3675 0.285  0.255 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.0025 0.     0.     0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.625
# Logical error over 7 cycles (single logical qubit): [0.385  0.36   0.3875 0.3425]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.665
# Logical error over 7 cycles (single logical qubit): [0.405  0.3925 0.27   0.3   ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6225
# Logical error over 7 cycles (single logical qubit): [0.3775 0.35   0.3775 0.3475]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6225
# Logical error over 7 cycles (single logical qubit): [0.39   0.3125 0.2625 0.2625]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.625
# Logical error over 7 cycles (single logical qubit): [0.3775 0.3575 0.3675 0.34  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.645
# Logical error over 7 cycles (single logical qubit): [0.3775 0.3675 0.28   0.27  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6074999999999999
# Logical error over 7 cycles (single logical qubit): [0.36   0.3275 0.3725 0.335 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.7
# Logical error over 7 cycles (single logical qubit): [0.4275 0.39   0.2925 0.3   ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.615
# Logical error over 7 cycles (single logical qubit): [0.3875 0.35   0.3475 0.3225]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6799999999999999
# Logical error over 7 cycles (single logical qubit): [0.4175 0.3775 0.305  0.3175]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6074999999999999
# Logical error over 7 cycles (single logical qubit): [0.4175 0.3675 0.415  0.3125]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.605
# Logical error over 7 cycles (single logical qubit): [0.345  0.34   0.27   0.2425]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6074999999999999
# Logical error over 7 cycles (single logical qubit): [0.355  0.3475 0.3575 0.3725]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6475
# Logical error over 7 cycles (single logical qubit): [0.4275 0.3825 0.265  0.25  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.61
# Logical error over 7 cycles (single logical qubit): [0.3475 0.345  0.35   0.3275]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.     0.0025 0.     0.0025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.65
# Logical error over 7 cycles (single logical qubit): [0.3825 0.38   0.275  0.2625]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6275
# Logical error over 7 cycles (single logical qubit): [0.34  0.37  0.335 0.395]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.7025
# Logical error over 7 cycles (single logical qubit): [0.41   0.45   0.315  0.2875]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.62
# Logical error over 7 cycles (single logical qubit): [0.3925 0.35   0.3675 0.3275]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6575
# Logical error over 7 cycles (single logical qubit): [0.395  0.36   0.265  0.2825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.585
# Logical error over 7 cycles (single logical qubit): [0.3    0.3425 0.35   0.32  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0024999999999999467
# Logical error over 7 cycles (single logical qubit): [0.     0.0025 0.     0.0025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6775
# Logical error over 7 cycles (single logical qubit): [0.4025 0.3625 0.295  0.2975]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.635
# Logical error over 7 cycles (single logical qubit): [0.375  0.3525 0.3625 0.35  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.625
# Logical error over 7 cycles (single logical qubit): [0.36   0.3625 0.2875 0.23  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6125
# Logical error over 7 cycles (single logical qubit): [0.3275 0.3675 0.3525 0.3175]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6225
# Logical error over 7 cycles (single logical qubit): [0.35   0.375  0.235  0.2825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.585
# Logical error over 7 cycles (single logical qubit): [0.365  0.3275 0.3575 0.315 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6950000000000001
# Logical error over 7 cycles (single logical qubit): [0.41   0.415  0.325  0.3025]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6025
# Logical error over 7 cycles (single logical qubit): [0.3725 0.335  0.3525 0.3475]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.64
# Logical error over 7 cycles (single logical qubit): [0.3425 0.3475 0.29   0.2775]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.63
# Logical error over 7 cycles (single logical qubit): [0.365  0.3775 0.315  0.3125]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6875
# Logical error over 7 cycles (single logical qubit): [0.375  0.395  0.2875 0.2825]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6125
# Logical error over 7 cycles (single logical qubit): [0.2975 0.37   0.315  0.3875]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.6625
# Logical error over 7 cycles (single logical qubit): [0.39   0.37   0.315  0.2725]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.6475
# Logical error over 7 cycles (single logical qubit): [0.365 0.415 0.37  0.405]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.0
# Logical error over 7 cycles (single logical qubit): [0. 0. 0. 0.]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9175
# Logical error over 7 cycles (single logical qubit): [0.4775 0.4875 0.47   0.4275]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.007499999999999951
# Logical error over 7 cycles (single logical qubit): [0.0025 0.0025 0.005  0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.855
# Logical error over 7 cycles (single logical qubit): [0.4575 0.4825 0.5025 0.4975]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.0075 0.01   0.01   0.01  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.915
# Logical error over 7 cycles (single logical qubit): [0.485  0.495  0.455  0.4575]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.01   0.01   0.0075 0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9075
# Logical error over 7 cycles (single logical qubit): [0.495  0.5025 0.525  0.46  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.0125 0.01   0.01   0.01  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8925
# Logical error over 7 cycles (single logical qubit): [0.51   0.4625 0.44   0.4525]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.0075 0.0075 0.0025 0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9075
# Logical error over 7 cycles (single logical qubit): [0.51   0.48   0.4975 0.505 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03249999999999997
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0225 0.025  0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9075
# Logical error over 7 cycles (single logical qubit): [0.58  0.455 0.43  0.48 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.005  0.01   0.0125 0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.915
# Logical error over 7 cycles (single logical qubit): [0.505  0.4975 0.4425 0.56  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.0225 0.02   0.0125 0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.905
# Logical error over 7 cycles (single logical qubit): [0.4925 0.495  0.4675 0.455 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.0125 0.01   0.01   0.0125]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8925
# Logical error over 7 cycles (single logical qubit): [0.5175 0.4475 0.48   0.4425]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.01   0.0125 0.0075 0.01  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8975
# Logical error over 7 cycles (single logical qubit): [0.48   0.54   0.4425 0.4575]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.0125 0.015  0.005  0.    ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.85
# Logical error over 7 cycles (single logical qubit): [0.5    0.4375 0.4425 0.445 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.01  0.005 0.015 0.005]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.915
# Logical error over 7 cycles (single logical qubit): [0.4575 0.53   0.48   0.495 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.007499999999999951
# Logical error over 7 cycles (single logical qubit): [0.0025 0.0025 0.005  0.    ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8575
# Logical error over 7 cycles (single logical qubit): [0.4775 0.475  0.51   0.455 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.03749999999999998
# Logical error over 7 cycles (single logical qubit): [0.015  0.0225 0.0225 0.025 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.905
# Logical error over 7 cycles (single logical qubit): [0.5025 0.4825 0.4675 0.5025]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.0125 0.0025 0.0025 0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8825000000000001
# Logical error over 7 cycles (single logical qubit): [0.525  0.4675 0.5    0.47  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.030000000000000027
# Logical error over 7 cycles (single logical qubit): [0.02   0.02   0.0175 0.02  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9025
# Logical error over 7 cycles (single logical qubit): [0.475  0.4675 0.5    0.4575]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.0125 0.005  0.01   0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.87
# Logical error over 7 cycles (single logical qubit): [0.4625 0.4975 0.465  0.4825]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.0125 0.015  0.015  0.0075]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9299999999999999
# Logical error over 7 cycles (single logical qubit): [0.5525 0.48   0.5025 0.4275]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.0225 0.015  0.0075 0.01  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8975
# Logical error over 7 cycles (single logical qubit): [0.51   0.5025 0.51   0.475 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.012499999999999956
# Logical error over 7 cycles (single logical qubit): [0.0075 0.0025 0.005  0.0025]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.89
# Logical error over 7 cycles (single logical qubit): [0.5175 0.4625 0.43   0.485 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.015  0.0125 0.005  0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.885
# Logical error over 7 cycles (single logical qubit): [0.495  0.4725 0.54   0.4575]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.02  0.02  0.02  0.015]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9275
# Logical error over 7 cycles (single logical qubit): [0.5375 0.4975 0.4525 0.47  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.010000000000000009
# Logical error over 7 cycles (single logical qubit): [0.0075 0.01   0.     0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8925
# Logical error over 7 cycles (single logical qubit): [0.4625 0.4925 0.4975 0.485 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.040000000000000036
# Logical error over 7 cycles (single logical qubit): [0.0325 0.025  0.03   0.0275]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.92
# Logical error over 7 cycles (single logical qubit): [0.49   0.5125 0.4425 0.4325]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.012499999999999956
# Logical error over 7 cycles (single logical qubit): [0.0075 0.     0.01   0.0025]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8875
# Logical error over 7 cycles (single logical qubit): [0.4875 0.47   0.51   0.4675]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.02749999999999997
# Logical error over 7 cycles (single logical qubit): [0.0225 0.025  0.0125 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.88
# Logical error over 7 cycles (single logical qubit): [0.4425 0.4825 0.4225 0.4   ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.010000000000000009
# Logical error over 7 cycles (single logical qubit): [0.005  0.005  0.0025 0.0075]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8775
# Logical error over 7 cycles (single logical qubit): [0.4725 0.4775 0.4775 0.465 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.0125 0.005  0.01   0.01  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9175
# Logical error over 7 cycles (single logical qubit): [0.48   0.55   0.46   0.4725]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.020000000000000018
# Logical error over 7 cycles (single logical qubit): [0.0125 0.015  0.0075 0.01  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.89
# Logical error over 7 cycles (single logical qubit): [0.49   0.4775 0.505  0.4475]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.015000000000000013
# Logical error over 7 cycles (single logical qubit): [0.005  0.005  0.0075 0.0075]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.865
# Logical error over 7 cycles (single logical qubit): [0.505  0.4825 0.4475 0.42  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.015  0.     0.0075 0.0175]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8674999999999999
# Logical error over 7 cycles (single logical qubit): [0.4625 0.455  0.4825 0.4475]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.0175 0.0175 0.0125 0.015 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.895
# Logical error over 7 cycles (single logical qubit): [0.475  0.4825 0.465  0.4675]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.02   0.0125 0.0075 0.0075]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8975
# Logical error over 7 cycles (single logical qubit): [0.4925 0.485  0.5225 0.49  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.015  0.0125 0.01   0.0175]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.8925
# Logical error over 7 cycles (single logical qubit): [0.475  0.505  0.4075 0.445 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.025000000000000022
# Logical error over 7 cycles (single logical qubit): [0.01   0.015  0.0025 0.005 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.91
# Logical error over 7 cycles (single logical qubit): [0.51   0.5225 0.44   0.47  ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.01749999999999996
# Logical error over 7 cycles (single logical qubit): [0.01   0.01   0.0075 0.0075]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.915
# Logical error over 7 cycles (single logical qubit): [0.5125 0.495  0.47   0.4175]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.012499999999999956
# Logical error over 7 cycles (single logical qubit): [0.0125 0.01   0.005  0.0075]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.8674999999999999
# Logical error over 7 cycles (single logical qubit): [0.47   0.4875 0.4925 0.5025]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.020000000000000018
# Logical error over 7 cycles (single logical qubit): [0.0125 0.01   0.0075 0.01  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9375
# Logical error over 7 cycles (single logical qubit): [0.5025 0.5125 0.4825 0.515 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.022499999999999964
# Logical error over 7 cycles (single logical qubit): [0.015  0.0075 0.0025 0.005 ]
# no error correction for logical X basis:
# ...
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.484 0.516 0.508 0.496]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.872
# Logical error over 7 cycles (single logical qubit): [0.48  0.512 0.488 0.5  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.908
# Logical error over 7 cycles (single logical qubit): [0.464 0.496 0.528 0.508]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.88
# Logical error over 7 cycles (single logical qubit): [0.42  0.452 0.496 0.42 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.54  0.464 0.54  0.476]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.888
# Logical error over 7 cycles (single logical qubit): [0.496 0.476 0.52  0.5  ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.552 0.528 0.484 0.504]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.876
# Logical error over 7 cycles (single logical qubit): [0.492 0.436 0.428 0.44 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.488 0.496 0.484 0.496]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.876
# Logical error over 7 cycles (single logical qubit): [0.532 0.46  0.504 0.464]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.94
# Logical error over 7 cycles (single logical qubit): [0.464 0.468 0.528 0.508]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.484 0.436 0.476 0.428]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.62  0.452 0.488 0.512]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.872
# Logical error over 7 cycles (single logical qubit): [0.432 0.456 0.44  0.448]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.964
# Logical error over 7 cycles (single logical qubit): [0.54  0.444 0.5   0.528]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.876
# Logical error over 7 cycles (single logical qubit): [0.488 0.524 0.5   0.468]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9
# Logical error over 7 cycles (single logical qubit): [0.432 0.536 0.528 0.48 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.504 0.464 0.372 0.48 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.464 0.508 0.488 0.488]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.888
# Logical error over 7 cycles (single logical qubit): [0.484 0.46  0.404 0.496]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.908
# Logical error over 7 cycles (single logical qubit): [0.516 0.476 0.512 0.54 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.896
# Logical error over 7 cycles (single logical qubit): [0.492 0.492 0.444 0.492]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.496 0.524 0.472 0.508]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.464 0.476 0.432 0.448]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.484 0.496 0.48  0.572]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.868
# Logical error over 7 cycles (single logical qubit): [0.484 0.52  0.468 0.42 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.476 0.464 0.536 0.452]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.896
# Logical error over 7 cycles (single logical qubit): [0.44  0.448 0.508 0.464]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.92
# Logical error over 7 cycles (single logical qubit): [0.484 0.508 0.452 0.488]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.444 0.472 0.504 0.46 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.904
# Logical error over 7 cycles (single logical qubit): [0.512 0.484 0.496 0.46 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.52  0.452 0.452 0.44 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.508 0.48  0.492 0.468]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.864
# Logical error over 7 cycles (single logical qubit): [0.452 0.468 0.46  0.484]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.528 0.536 0.492 0.472]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.448 0.468 0.448 0.436]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.48  0.524 0.5   0.472]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.464 0.488 0.496 0.452]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.508 0.464 0.54  0.52 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.876
# Logical error over 7 cycles (single logical qubit): [0.452 0.476 0.468 0.44 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.492 0.468 0.512 0.48 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.908
# Logical error over 7 cycles (single logical qubit): [0.508 0.508 0.48  0.476]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.908
# Logical error over 7 cycles (single logical qubit): [0.528 0.48  0.476 0.516]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.904
# Logical error over 7 cycles (single logical qubit): [0.48  0.472 0.5   0.456]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.916
# Logical error over 7 cycles (single logical qubit): [0.508 0.476 0.46  0.56 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.5   0.448 0.476 0.512]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.488 0.436 0.54  0.52 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.832
# Logical error over 7 cycles (single logical qubit): [0.46  0.452 0.432 0.46 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.524 0.54  0.5   0.488]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.912
# Logical error over 7 cycles (single logical qubit): [0.54  0.46  0.492 0.544]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.94
# Logical error over 7 cycles (single logical qubit): [0.524 0.512 0.512 0.52 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.476 0.504 0.468 0.468]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.956
# Logical error over 7 cycles (single logical qubit): [0.512 0.512 0.528 0.548]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.504 0.496 0.488 0.472]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.548 0.484 0.464 0.488]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.5   0.504 0.424 0.392]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.524 0.452 0.476 0.512]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.484 0.484 0.472 0.528]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.928
# Logical error over 7 cycles (single logical qubit): [0.516 0.548 0.504 0.48 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.504 0.464 0.436 0.456]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.544 0.556 0.476 0.48 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.892
# Logical error over 7 cycles (single logical qubit): [0.488 0.472 0.48  0.552]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.492 0.528 0.572 0.456]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.86
# Logical error over 7 cycles (single logical qubit): [0.472 0.42  0.472 0.472]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.972
# Logical error over 7 cycles (single logical qubit): [0.536 0.532 0.492 0.496]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.892
# Logical error over 7 cycles (single logical qubit): [0.484 0.44  0.492 0.488]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.468 0.532 0.508 0.524]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.896
# Logical error over 7 cycles (single logical qubit): [0.52  0.476 0.46  0.456]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.492 0.476 0.52  0.572]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.888
# Logical error over 7 cycles (single logical qubit): [0.408 0.476 0.456 0.472]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.536 0.548 0.504 0.516]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.856
# Logical error over 7 cycles (single logical qubit): [0.464 0.448 0.448 0.456]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.944
# Logical error over 7 cycles (single logical qubit): [0.528 0.52  0.476 0.492]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.896
# Logical error over 7 cycles (single logical qubit): [0.488 0.48  0.5   0.476]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.508 0.556 0.508 0.44 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.848
# Logical error over 7 cycles (single logical qubit): [0.4   0.548 0.392 0.468]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.948
# Logical error over 7 cycles (single logical qubit): [0.524 0.436 0.544 0.504]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.872
# Logical error over 7 cycles (single logical qubit): [0.5   0.432 0.464 0.48 ]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9319999999999999
# Logical error over 7 cycles (single logical qubit): [0.512 0.472 0.448 0.504]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.844
# Logical error over 7 cycles (single logical qubit): [0.428 0.476 0.428 0.44 ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.952
# Logical error over 7 cycles (single logical qubit): [0.5   0.504 0.508 0.564]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.88
# Logical error over 7 cycles (single logical qubit): [0.488 0.52  0.472 0.408]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.9359999999999999
# Logical error over 7 cycles (single logical qubit): [0.464 0.544 0.492 0.54 ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.804
# Logical error over 7 cycles (single logical qubit): [0.392 0.404 0.392 0.396]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.912
# Logical error over 7 cycles (single logical qubit): [0.492 0.476 0.472 0.52 ]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.884
# Logical error over 7 cycles (single logical qubit): [0.504 0.476 0.476 0.508]
# no error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.94
# Logical error over 7 cycles (single logical qubit): [0.448 0.516 0.492 0.5  ]
#
#
# error correction for logical Z basis:
# Logical error over 7 cycles (four logical qubits): 0.924
# Logical error over 7 cycles (single logical qubit): [0.476 0.488 0.484 0.512]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.94
# Logical error over 7 cycles (single logical qubit): [0.492 0.5   0.492 0.524]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.864
# Logical error over 7 cycles (single logical qubit): [0.48  0.452 0.456 0.492]
# The total running time: 545.55 seconds
