# %%
import numpy as np
from tabulate import tabulate
import os
import sys
# print(sys.executable)
from scipy.io import savemat
from scipy.io import loadmat
from scipy.optimize import curve_fit

# %%
import pickle
import matplotlib.pyplot as plt 
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as ticker

# %%
n2 = 9 ;
k = 4 ;
remove_X_list = [2,8] ;  remove_Z_list = [3,4] ;

# %%
max_num_cycles = 6;

# %% [markdown]
# ### Run numerical simulation to obtain data

# %%
import subprocess
script = "Classical_simulation_18_4_4.py"
cycles = range(1, max_num_cycles+1)

processes = []
for cycle in cycles:
    p = subprocess.Popen([sys.executable, script, str(cycle)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()

# %% [markdown]
# ### Perform error correction on numerical data

# %%
import subprocess
script = "Error_correction_classical_simulation_18_4_4.py"
cycles = range(1, max_num_cycles+1)

processes = []
for cycle in cycles:
    p = subprocess.Popen([sys.executable, script, str(cycle)])
    processes.append(p)

# 等待所有进程完成
for p in processes:
    p.wait()
# Out:
# no error correction:
# Logical error over 2 cycles (four logical qubits): 0.684975
# Logical error over 2 cycles (single logical qubit): [0.36065  0.386425 0.28995  0.300075]
#
#
# error correction:
# Logical error over 2 cycles (four logical qubits): 0.376
# Logical error over 2 cycles (single logical qubit): [0.19255  0.1973   0.2124   0.203625]
# no error correction for logical X basis:
# Logical error over 2 cycles (four logical qubits): 0.64915
# Logical error over 2 cycles (single logical qubit): [0.3537   0.358825 0.282175 0.35625 ]
#
#
# error correction for logical X basis:
# Logical error over 2 cycles (four logical qubits): 0.36712500000000003
# Logical error over 2 cycles (single logical qubit): [0.207325 0.20605  0.193525 0.18805 ]
# no error correction:
# Logical error over 3 cycles (four logical qubits): 0.823225
# Logical error over 3 cycles (single logical qubit): [0.43615  0.454075 0.37485  0.386175]
#
#
# error correction:
# Logical error over 3 cycles (four logical qubits): 0.565025
# Logical error over 3 cycles (single logical qubit): [0.30025  0.28825  0.311775 0.30995 ]
# no error correction for logical X basis:
# Logical error over 3 cycles (four logical qubits): 0.807925
# Logical error over 3 cycles (single logical qubit): [0.435425 0.44055  0.380975 0.439125]
#
#
# error correction for logical X basis:
# Logical error over 3 cycles (four logical qubits): 0.5965750000000001
# Logical error over 3 cycles (single logical qubit): [0.335975 0.328475 0.31235  0.313175]
# no error correction:
# Logical error over 4 cycles (four logical qubits): 0.8842
# Logical error over 4 cycles (single logical qubit): [0.4754   0.483925 0.42415  0.441725]
#
#
# error correction:
# Logical error over 4 cycles (four logical qubits): 0.6979500000000001
# Logical error over 4 cycles (single logical qubit): [0.371625 0.363325 0.384925 0.3795  ]
# no error correction for logical X basis:
# Logical error over 4 cycles (four logical qubits): 0.875525
# Logical error over 4 cycles (single logical qubit): [0.473175 0.471325 0.431    0.474475]
#
#
# error correction for logical X basis:
# Logical error over 4 cycles (four logical qubits): 0.73305
# Logical error over 4 cycles (single logical qubit): [0.402925 0.400275 0.394825 0.38425 ]
# no error correction:
# Logical error over 5 cycles (four logical qubits): 0.909775
# Logical error over 5 cycles (single logical qubit): [0.48785  0.4927   0.4583   0.465725]
#
#
# error correction:
# Logical error over 5 cycles (four logical qubits): 0.7871
# Logical error over 5 cycles (single logical qubit): [0.420925 0.409825 0.4294   0.42645 ]
# no error correction for logical X basis:
# Logical error over 5 cycles (four logical qubits): 0.908675
# Logical error over 5 cycles (single logical qubit): [0.49     0.4895   0.462625 0.48525 ]
#
#
# error correction for logical X basis:
# Logical error over 5 cycles (four logical qubits): 0.82155
# Logical error over 5 cycles (single logical qubit): [0.4483   0.4488   0.437825 0.4332  ]
# no error correction:
# Logical error over 6 cycles (four logical qubits): 0.9249
# Logical error over 6 cycles (single logical qubit): [0.495075 0.494975 0.478375 0.47905 ]
#
#
# error correction:
# Logical error over 6 cycles (four logical qubits): 0.8417749999999999
# Logical error over 6 cycles (single logical qubit): [0.449975 0.4437   0.454875 0.4501  ]
# no error correction for logical X basis:
# Logical error over 6 cycles (four logical qubits): 0.926625
# Logical error over 6 cycles (single logical qubit): [0.498425 0.493225 0.482    0.496575]
#
#
# error correction for logical X basis:
# Logical error over 6 cycles (four logical qubits): 0.8673
# Logical error over 6 cycles (single logical qubit): [0.46595  0.466225 0.46455  0.45545 ]
# no error correction:
# Logical error over 7 cycles (four logical qubits): 0.930875
# Logical error over 7 cycles (single logical qubit): [0.494625 0.495275 0.4833   0.492925]
#
#
# error correction:
# Logical error over 7 cycles (four logical qubits): 0.8785499999999999
# Logical error over 7 cycles (single logical qubit): [0.470875 0.463075 0.47325  0.4715  ]
# no error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.92985
# Logical error over 7 cycles (single logical qubit): [0.501925 0.497925 0.489225 0.496075]
#
#
# error correction for logical X basis:
# Logical error over 7 cycles (four logical qubits): 0.897625
# Logical error over 7 cycles (single logical qubit): [0.481175 0.4814   0.476475 0.474   ]

# %%
set_syndrome_history_X = {}
for cycle in range(1, max_num_cycles+1):
    fname = './Numerical_results/' + 'Logical_X_' + 'num_cycles_' + str(cycle) + '.mat'
    data = loadmat(fname)
    set_syndrome_history_X[f"cycle_{cycle}"] = data['syndrome_history_X']

# %%
set_syndrome_history_Z = {}
for cycle in range(1, max_num_cycles+1):
    fname = './Numerical_results/' + 'Logical_Z_' + 'num_cycles_' + str(cycle) + '.mat'
    data = loadmat(fname)
    set_syndrome_history_Z[f"cycle_{cycle}"] = data['syndrome_history_Z']

# %%
X_logical_error_probability = [];
X_logical_error_probability_perqubit = [] ;
for cycle in range(1, max_num_cycles+1):
    fname = './Numerical_results/' + 'Logical_X_' + 'num_cycles_' + str(cycle) + '.mat'
    data = loadmat(fname)
    X_logical_error_probability.append( data['logical_error_probability'][0][0] )
    X_logical_error_probability_perqubit.append(data['logical_error_probability_per_qubit'][0])

# %%
Z_logical_error_probability = [];
Z_logical_error_probability_perqubit = [] ;
for cycle in range(1, max_num_cycles+1):
    fname = './Numerical_results/' + 'Logical_Z_' + 'num_cycles_' + str(cycle) + '.mat'
    data = loadmat(fname)
    Z_logical_error_probability.append( data['logical_error_probability'][0][0]  )
    Z_logical_error_probability_perqubit.append(data['logical_error_probability_per_qubit'][0])

# %% [markdown]
# ## Error detection probability

# %% [markdown]
# ## logical Z state

# %%
labels_z = ['Z0', 'Z1', 'Z2', 'Z5', 'Z6', 'Z7', 'Z8']

num_zcheck = len(labels_z) ;

mean_detect_prob_z = np.mean(set_syndrome_history_Z[f"cycle_{max_num_cycles}"], axis=0)

mean_detect_prob_cycle_z = [ np.mean(mean_detect_prob_z[num_zcheck*cycle:num_zcheck*(cycle+1)]) for cycle in range(max_num_cycles+1) ]

for cycle in range(max_num_cycles+1) :
    print( f'The mean probability of error detection in cycle {cycle+1} is:', mean_detect_prob_cycle_z[cycle] )

per_z_detect_prob = [ [ mean_detect_prob_z[i + cycle*num_zcheck ] for cycle in range(max_num_cycles+1) ] for i in range(num_zcheck) ]
# Out:
# The mean probability of error detection in cycle 1 is: 0.1715357142857143
# The mean probability of error detection in cycle 2 is: 0.31452142857142856
# The mean probability of error detection in cycle 3 is: 0.3335464285714286
# The mean probability of error detection in cycle 4 is: 0.3345142857142857
# The mean probability of error detection in cycle 5 is: 0.33458214285714283
# The mean probability of error detection in cycle 6 is: 0.3348285714285714
# The mean probability of error detection in cycle 7 is: 0.3604178571428572

# %%
plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams['figure.figsize'] = 3, 2
plt.rcParams.update({'font.size': 5})

fig, ax = plt.subplots( dpi = 800)

ax.plot( range(1, max_num_cycles+2), mean_detect_prob_cycle_z, color = 'green', linestyle = "-", linewidth=1.1, 
        marker = 's', markersize = 2, label = "Z basis" )

for i in range( num_zcheck ):
    ax.plot( range(1, max_num_cycles+2), per_z_detect_prob[i], color = 'green', linestyle = "dotted", linewidth=0.5, 
        marker = '.', markersize = 1)

ax.legend(frameon=True, loc=(0.7, 0.2), labelspacing=0.4, fontsize='7')
ax.set_xlabel(r'Quantum error correction cycle, $N_c$', labelpad = 2) 
ax.set_ylabel(f'Detection prob., $p_d$', labelpad = 3) 

plt.tight_layout()
# plt.subplots_adjust(left = 0.145, bottom = 0.18, top = 0.99, right = 0.99) 
plt.show()
fig.savefig('Simulation_Figures/Z_detection_prob_18_4_4_simulation.pdf', format='pdf', bbox_inches='tight', facecolor='None')

# %% [markdown]
# ## logical X state

# %%
labels_x =  ['X0', 'X1', 'X3', 'X4', 'X5', 'X6', 'X7']

num_xcheck = len(labels_x) ;

mean_detect_prob_x = np.mean(set_syndrome_history_X[f"cycle_{max_num_cycles}"], axis=0)

mean_detect_prob_cycle_x = [ np.mean(mean_detect_prob_x[num_xcheck*cycle:num_xcheck*(cycle+1)]) for cycle in range(max_num_cycles+1) ]

for cycle in range(max_num_cycles+1) :
    print( f'The mean probability of error detection in cycle {cycle+1} is:', mean_detect_prob_cycle_x[cycle] )

per_x_detect_prob = [ [ mean_detect_prob_x[i + cycle*num_xcheck ] for cycle in range(max_num_cycles+1) ] for i in range(num_xcheck) ]
# Out:
# The mean probability of error detection in cycle 1 is: 0.21263214285714285
# The mean probability of error detection in cycle 2 is: 0.34078571428571436
# The mean probability of error detection in cycle 3 is: 0.3536892857142857
# The mean probability of error detection in cycle 4 is: 0.35432142857142856
# The mean probability of error detection in cycle 5 is: 0.35511071428571434
# The mean probability of error detection in cycle 6 is: 0.35419285714285714
# The mean probability of error detection in cycle 7 is: 0.34179642857142856

# %%
plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams['figure.figsize'] = 3, 2
plt.rcParams.update({'font.size': 5})

fig, ax = plt.subplots( dpi = 800)

ax.plot( range(1, max_num_cycles+2), mean_detect_prob_cycle_x, color = 'purple', linestyle = "-", linewidth=1.1, 
        marker = 's', markersize = 2, label = "X basis" )

for i in range( num_xcheck ):
    ax.plot( range(1, max_num_cycles+2), per_x_detect_prob[i], color = 'purple', linestyle = "dotted", linewidth=0.5, 
        marker = '.', markersize = 1)

ax.legend(frameon=True, loc=(0.7, 0.2), labelspacing=0.4, fontsize='7')
ax.set_xlabel(r'Quantum error correction cycle, $N_c$', labelpad = 2) 
ax.set_ylabel(f'Detection prob., $p_d$', labelpad = 3) 

plt.tight_layout()
# plt.subplots_adjust(left = 0.145, bottom = 0.18, top = 0.99, right = 0.99) 
plt.show()
fig.savefig('Simulation_Figures/X_detection_prob_18_4_4_simulation.pdf', format='pdf', bbox_inches='tight', facecolor='None')

# %% [markdown]
# ## Logical-state preservation and error per cycle

# %%
def four_to_one(p, k):
    return 1-(1-p)**(1/k)

def physical_p_per_cycle(cycle_time, T):
    return (1-np.exp(-cycle_time/T))/2

T1 = 40 #us
T2 = 20 #us
cycle_time = 1.785 #us

# %%
# accumulated error rate for four physical qubits
# physical Z state (four qubits)
cycle_t_physical = np.linspace(1, max_num_cycles+1) ;
physical_error_single_qubit_z = [physical_p_per_cycle(cycle_time*t, T1) for t in cycle_t_physical]
physical_error_four_qubits_z =  [ 1 - (1 - item)**k for item in physical_error_single_qubit_z ]  ;

physical_error_single_qubit_x = [physical_p_per_cycle(cycle_time*t, T2) for t in cycle_t_physical]
physical_error_four_qubits_x =  [ 1 - (1 - item)**k for item in physical_error_single_qubit_x ]  ;

# %% [markdown]
# ## logical Z state

# %% [markdown]
# Define the logical fidelity for four distance-$4$ logical qubits : $F(t) = 1- P_L(t)$, then we have $F(t+1) = (1 - p_L) \cdot F(t)$, where $p_L$ is the logical error per cycle.
#
# We fit $F(t) = B \cdot A^{t}$, where $A = 1 - p_L$.
#
# We start the fit from cycle $3$.

# %%
# Z_logical_error_probability

# %%
cycle_t_logical = np.arange(1, max_num_cycles+1) ;
Z_logical_Fidelity = 1 - np.array( Z_logical_error_probability[0:] )
log_Z_logical_Fidelity = np.log(Z_logical_Fidelity)

coefficients = np.polyfit(cycle_t_logical, log_Z_logical_Fidelity, 1)
log_A, log_B = coefficients  # [斜率, 截距]

# 转换回原始参数
A = np.exp(log_A)
B = np.exp(log_B)

Logical_error_four_qubits_per_cycle_Z = 1 - A
print(f"Logical error rate for four logical qubits per cycle = {Logical_error_four_qubits_per_cycle_Z}")

Logical_error_single_qubit_per_cycle_Z = 1-A**(1/k)
print(f"Logical error rate for a single logical qubit per cycle = {Logical_error_single_qubit_per_cycle_Z}")

Logical_T1 = -cycle_time/np.log(1 - 2 * Logical_error_single_qubit_per_cycle_Z)
print(f"Logical T_1 for four logical qubits per cycle = {Logical_T1}")
# Out:
# Logical error rate for four logical qubits per cycle = 0.2814216782177589
# Logical error rate for a single logical qubit per cycle = 0.07929918455839424
# Logical T_1 for four logical qubits per cycle = 10.336670301122005

# %%
# The fit line
cycle_interpo = np.linspace(1, max_num_cycles+1, 100) ;
pred_Z_logical_error_probability = (1 - B * A**(cycle_interpo))

# %%
color_list = ["cyan", "grey", "blue", "red"] ;
plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams['figure.figsize'] = 3.2, 3.2
plt.rcParams.update({'font.size': 5})

fig, ax = plt.subplots( dpi = 800)

# Z_logical_error_propability.insert(0, None)
ax.set_xlim(0, 7.2)
ax.set_ylim(0, 1)
#----------------------------------------------------------------------
ax.plot( range(1, max_num_cycles+1), Z_logical_error_probability, color = 'green', linestyle = "", linewidth=1.2, 
        marker = '.', markersize = 6, label = 'four logical qubits' )
ax.plot( range(1, max_num_cycles+1), four_to_one( np.array(Z_logical_error_probability), 4), color = 'plum', linestyle = "", linewidth=1.2, 
        marker = '.', markersize = 6, label = 'estimated single logical qubit' )
#----------------------------------------------------------------------
for i in range(k):
    ax.plot( range(1, max_num_cycles+1), [item[i] for item in Z_logical_error_probability_perqubit], color = color_list[i], \
            linestyle = "", linewidth=1.2, marker = '.', markersize = 2, label = f'logical qubit {i+1}' )
#----------------------------------------------------------------------

ax.plot( cycle_interpo, pred_Z_logical_error_probability, color = 'black', linestyle = "solid", linewidth=1)

#----------------------------------------------------------------------
ax.plot( np.linspace(1, max_num_cycles+1), physical_error_single_qubit_z , color = 'green', linestyle = "-.", \
        linewidth=1, marker = 'o', markerfacecolor = "white", markersize = 0.4, label = 'single physical qubit')

ax.plot( np.linspace(1, max_num_cycles+1), physical_error_four_qubits_z, color = 'red', linestyle = "-.", \
        linewidth=1, marker = 'o', markerfacecolor = "white", markersize = 0.4, label = 'four physical qubits')
#----------------------------------------------------------------------
ax.legend(frameon=False, loc=(0.01, 0.67), labelspacing=0.6, fontsize='5')
ax.set_xlabel(r'Quantum error correction cycle, $N_c$   (logical Z basis)', labelpad = 2) 
ax.set_ylabel(r'Logical error probability, $P_L(N_c)$', labelpad = 3) 

plt.tight_layout()
# plt.subplots_adjust(left = 0.145, bottom = 0.18, top = 0.99, right = 0.99) 
plt.show()
fig.savefig('Simulation_Figures/Z_error_correction_18_4_4_simulation.pdf', format='pdf', bbox_inches='tight', facecolor='None')

# %% [markdown]
# ## logical X state

# %%
cycle_t_logical = np.arange(1, max_num_cycles+1) ;
X_logical_Fidelity = 1 - np.array( X_logical_error_probability[0:] )
log_X_logical_Fidelity = np.log(X_logical_Fidelity)

coefficients = np.polyfit(cycle_t_logical, log_X_logical_Fidelity, 1)
log_A2, log_B2 = coefficients  # [斜率, 截距]

# 转换回原始参数
A2 = np.exp(log_A2)
B2 = np.exp(log_B2)

Logical_error_four_qubits_per_cycle_X = 1 - A2
print(f"Logical error rate for four logical qubits per cycle = {Logical_error_four_qubits_per_cycle_X}")

Logical_error_single_qubit_per_cycle_X = 1 - A2**(1/k)
print(f"Logical error rate for a single logical qubit per cycle = {Logical_error_single_qubit_per_cycle_X}")

Logical_T2 = -cycle_time/np.log(1 - 2 * Logical_error_single_qubit_per_cycle_X)
print(f"Logical T_2 for four logical qubits per cycle = {Logical_T2}")
# Out:
# Logical error rate for four logical qubits per cycle = 0.3072221013802773
# Logical error rate for a single logical qubit per cycle = 0.08767724723945503
# Logical T_2 for four logical qubits per cycle = 9.25821830913316

# %%
# The fit line
cycle_interpo = np.linspace(1, max_num_cycles+1, 100) ;
pred_X_logical_error_probability = (1 - B2 * A2**(cycle_interpo))

# %%
color_list = ["cyan", "grey", "blue", "red"] ;
plt.rcParams["font.family"] = "DejaVu Sans"
plt.rcParams['figure.figsize'] = 3.2, 3.2
plt.rcParams.update({'font.size': 5})

fig, ax = plt.subplots( dpi = 800)
ax.set_xlim(0, 7.2)
ax.set_ylim(0, 1)

ax.plot( cycle_t_logical, X_logical_error_probability, color = 'purple', linestyle = "", linewidth=1.2, 
        marker = '.', markersize = 6, label = 'four logical qubits' )
ax.plot( range(1, max_num_cycles+1), four_to_one( np.array(X_logical_error_probability), 4), color = 'plum', linestyle = "", linewidth=1.2, 
        marker = '.', markersize = 6, label = 'estimated single logical qubit' )
#----------------------------------------------------------------------
for i in range(k):
    ax.plot( range(1, max_num_cycles+1), [item[i] for item in X_logical_error_probability_perqubit], color = color_list[i], \
            linestyle = "", linewidth=1.2, marker = '.', markersize = 2, label = f'logical qubit {i+1}' )
#----------------------------------------------------------------------

ax.plot( cycle_interpo, pred_X_logical_error_probability, color = 'black', linestyle = "solid", linewidth=1)


ax.plot( np.linspace(1, max_num_cycles+1), physical_error_single_qubit_x , color = 'green', linestyle = "-.", \
        linewidth=1, marker = 'o', markerfacecolor = "white", markersize = 0.4, label = 'single physical qubit')

ax.plot( cycle_t_physical, physical_error_four_qubits_x, color = 'red', linestyle = "-.", \
        linewidth=1, marker = 'o', markerfacecolor = "white", markersize = 0.4, label = 'four physical qubits')

ax.legend(frameon=False, loc=(0.01, 0.67), labelspacing=0.6, fontsize='5')
ax.set_xlabel(r'Quantum error correction cycle, $N_c$   (logical X basis)', labelpad = 2) 
ax.set_ylabel(r'Logical error probability, $P_L(N_c)$', labelpad = 3) 

plt.tight_layout()
# plt.subplots_adjust(left = 0.145, bottom = 0.18, top = 0.99, right = 0.99) 
plt.show()
fig.savefig('Simulation_Figures/X_error_correction_18_4_4_simulation.pdf', format='pdf', bbox_inches='tight', facecolor='None')
